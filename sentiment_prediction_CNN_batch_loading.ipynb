# %%
import numpy as np # 
import pandas as pd #
import matplotlib.pyplot as plt
import seaborn as sns
import spacy
import sqlite3

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/hashes.txt
# /kaggle/input/database.sqlite
# /kaggle/input/Reviews.csv

# %%
from sklearn.model_selection import train_test_split
from keras.preprocessing import sequence    # A helper module to handle padding input
from keras.models import Sequential         # The base keras Neural Network model
from keras.layers import Dense, Dropout, Activation   # The layer objects we will pile into the model
from keras.layers import Conv1D, GlobalMaxPooling1D
# Out:
# Using TensorFlow backend.

# %%
nlp = spacy.load('en_core_web_lg', disable=["parser", "entity_ruler",
                                           "sentencizer", "merge_noun_chunks",
                                           "merge_entities", "merge_subtokens"])

# %% [markdown]
# ### Train/Test Split by Index Id

# %%
con = sqlite3.connect('../input/database.sqlite')

# %%
df_rev_ids_scores = pd.read_sql_query("SELECT Id, Score FROM Reviews WHERE Score != 3;", con)

# %%
df_rev_ids_scores.head()
# Out:
#    Id  Score
# 0   1      5
# 1   2      1
# 2   3      4
# 3   4      2
# 4   5      5

# %%
y_labels = (df_rev_ids_scores.Score < 3).astype('int')

# %%
train_ids, test_ids, y_train, y_test = train_test_split(df_rev_ids_scores.Id, y_labels, 
                                                 test_size=0.2, random_state=2019, stratify=y_labels)

# %%
y_train.mean(), y_test.mean(), len(train_ids), len(test_ids)
# Out:
# (0.15602007364775075, 0.15601494822323442, 420651, 105163)

# %% [markdown]
# ### Testing data extraction

# %%
pd.read_sql_query("SELECT * FROM Reviews LIMIT 3", con)
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...

# %%
str(train_ids[:10])

# %%
id_list_str = ','.join([str(item) for item in train_ids[:10]])

# %%
id_list_str

# %%
query = """SELECT Id, Text FROM Reviews WHERE Id IN (%s)""" %id_list_str

# %%
query

# %%
df_sample = pd.read_sql_query(query, con)

# %%
df_sample

# %% [markdown]
# ### Loading samples for training one by one

# %%
pad_trunc_limit = 100
batch_size = 32
emb_dim = 300
# number of filters to train
n_filters = 250
# the width of the filters
kernel_size = 3
hidden_dim = 250
epochs = 10

# %%
model = Sequential()

# %%
model.add(Conv1D(n_filters,
                 kernel_size,
                 padding='valid',
                 activation='relu',
                 strides=1,
                 input_shape=(pad_trunc_limit, emb_dim)))
model.add(GlobalMaxPooling1D())
# hidden layer
model.add(Dense(hidden_dim))
# adding dropout to avoid overfitting
model.add(Dropout(0.1))
model.add(Activation('relu'))
# project into a single unit output layer
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
len(train_ids)
# Out:
# 420651

# %%
list(range(0, len(train_ids), 100000))
# Out:
# [0, 100000, 200000, 300000, 400000]

# %%
def pad_or_truncate(txt_mat, nsize=pad_trunc_limit):
    """
    pad or truncate set of GloVe vectors for every review
    """
    # get a length of given review
    nvect = txt_mat.shape[0]
    if nvect < 100:
        return np.concatenate([txt_mat, np.zeros([nsize - nvect, 300])])
    else:
        return txt_mat[:nsize,]

# %%
for sample_ix in range(0, len(train_ids), 10000):
    print("sample_ix:", sample_ix)
    y_train_sample = y_train[sample_ix:sample_ix + 10000]
    id_list_str = ','.join([str(item) 
                            for item in train_ids[sample_ix:sample_ix + 10000]])
    df_sample_text = pd.read_sql_query("SELECT Text FROM Reviews WHERE Id IN (%s)" %id_list_str, con)
    sample_docs = list(nlp.pipe(df_sample_text.Text))
    X_train_sample = [pad_or_truncate(np.array([tok.vector for tok in doc])) 
             for doc in sample_docs]
    X_train_sample = np.reshape(X_train_sample, ((len(X_train_sample), pad_trunc_limit, emb_dim)))
    
    # training phase
    model.fit(X_train_sample, y_train_sample,
          batch_size=batch_size,
          epochs=epochs,
          validation_split=0
10
# 9000/9000 [==============================] - 13s 1ms/step - loss: 0.0288 - acc: 0.9937 - val_loss: 1.2452 - val_acc: 0.8090
# sample_ix: 30000
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/10
# 9000/9000 [==============================] - 13s 1ms/step - loss: 0.5139 - acc: 0.8213 - val_loss: 0.4638 - val_acc: 0.8280
# Epoch 2/10
# 9000/9000 [==============================] - 13s 1ms/step - loss: 0.4279 - acc: 0.8404 - val_loss: 0.4734 - val_acc: 0.8280
# Epoch 3/10
# 9000/9000 [==============================] - 13s 1ms/step - loss: 0.3951 - acc: 0.8443 - val_loss: 0.5022 - val_acc: 0.8270
# Epoch 4/10
# 9000/9000 [==============================] - 13s 1ms/step - loss: 0.3108 - acc: 0.8702 - val_loss: 0.5714 - val_acc: 0.7920
# Epoch 5/10
# 9000/9000 [==============================] - 13s 1ms/step - loss: 0.1998 - acc: 0.9233 - val_loss: 0.7089 - val_acc: 0.7430
# Epoch 6/10
# 9000/9000 [==============================] - 13s 1ms/step - loss: 0.1135 - acc: 0.9611 - val_loss: 0.8836 - val_acc: 0.7740
# Epoch 7/10
# 9000/9000 [==============================] - 13s 1ms/step - loss: 0.0699 - acc: 0.9810 - val_loss: 1.1452 - val_acc: 0.8030
# Epoch 8/10
# 9000/9000 [==============================] - 13s 1ms/step - loss: 0.0532 - acc: 0.9897 - val_loss: 1.1664 - val_acc: 0.7890
# Epoch 9/10
# 9000/9000 [==============================] - 13s 1ms/step - loss: 0.0441 - acc: 0.9907 - val_loss: 1.3659 - val_acc: 0.8120
# Epoch 10/10
# 9000/9000 [==============================] - 13s 1ms/step - loss: 0.0381 - acc: 0.9929 - val_loss: 1.4946 - val_acc: 0.8120
# sample_ix: 40000
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/10
# 9000/9000 [==============================] - 13s 1ms/step - loss: 0.4685 - acc: 0.8436 - val_loss: 0.4460 - val_acc: 0.8420
# Epoch 2/10
# 9000/9000 [==============================] - 13s 1ms/step - loss: 0.4134 - acc: 0.8504 - val_loss: 0.4600 - val_acc: 0.8390
# Epoch 3/10
# 9000/9000 [==============================] - 13s 1ms/step - loss: 0.3799 - acc: 0.8533 - val_loss: 0.4741 - val_acc: 0.8400
# Epoch 4/10
# 9000/9000 [==============================] - 13s 1ms/step - loss: 0.3007 - acc: 0.8718 - val_loss: 0.5902 - val_acc: 0.8360
# Epoch 5/10
# 9000/9000 [==============================] - 13s 1ms/step - loss: 0.1900 - acc: 0.9246 - val_loss: 0.7387 - val_acc: 0.8090
# Epoch 6/10
# 9000/9000 [==============================] - 13s 1ms/step - loss: 0.0966 - acc: 0.9663 - val_loss: 0.9695 - val_acc: 0.8160
# Epoch 7/10
# 9000/9000 [==============================] - 13s 1ms/step - loss: 0.0589 - acc: 0.9836 - val_loss: 1.0681 - val_acc: 0.7820
# Epoch 8/10
# 9000/9000 [==============================] - 13s 1ms/step - loss: 0.0417 - acc: 0.9894 - val_loss: 1.1373 - val_acc: 0.7970
# Epoch 9/10
# 9000/9000 [==============================] - 13s 1ms/step - loss: 0.0268 - acc: 0.9927 - val_loss: 1.3166 - val_acc: 0.8020
# Epoch 10/10
# 9000/9000 [==============================] - 13s 1ms/step - loss: 0.0196 - acc: 0.9927 - val_loss: 1.3783 - val_acc: 0.8090
# sample_ix: 50000
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/10
# 9000/9000 [==============================] - 13s 1ms/step - loss: 0.4833 - acc: 0.8371 - val_loss: 0.4409 - val_acc: 0.8480
# Epoch 2/10
# 9000/9000 [==============================] - 13s 1ms/step - loss: 0.4354 - acc: 0.8409 - val_loss: 0.4363 - val_acc: 0.8480
# Epoch 3/10
# 9000/9000 [==============================] - 13s 1ms/step - loss: 0.4122 - acc: 0.8407 - val_loss: 0.4490 - val_acc: 0.8480
# Epoch 4/10
# 9000/9000 [==============================] - 13s 1ms/step - loss: 0.3510 - acc: 0.8413 - val_loss: 0.4935 - val_acc: 0.8480
# Epoch 5/10
# 9000/9000 [==============================] - 13s 1ms/step - loss: 0.2563 - acc: 0.8799 - val_loss: 0.6055 - val_acc: 0.8090
# Epoch 6/10
# 9000/9000 [==============================] - 13s 1ms/step - loss: 0.1471 - acc: 0.9414 - val_loss: 1.1211 - val_acc: 0.8340
# Epoch 7/10
# 9000/9000 [==============================] - 13s 1ms/step - loss: 0.0821 - acc: 0.9739 - val_loss: 1.1133 - val_acc: 0.8040
# Epoch 8/10
# 9000/9000 [==============================] - 13s 1ms/step - loss: 0.0580 - acc: 0.9851 - val_loss: 1.3381 - val_acc: 0.8140
# Epoch 9/10
# 9000/9000 [==============================] - 13s 1ms/step - loss: 0.0424 - acc: 0.9904 - val_loss: 1.3352 - val_acc: 0.8100
# Epoch 10/10
# 9000/9000 [==============================] - 13s 1ms/step - loss: 0.0351 - acc: 0.9923 - val_loss: 1.5277 - val_acc: 0.8190
# sample_ix: 60000

# %%
id_list_str = ','.join([str(item) for item in train_ids[:10]])

# %%
df_sample_text = pd.read_sql_query(query, con)

# %%
all_docs = list(nlp.pipe(df_rev[df_rev.Score!=3].Text))
